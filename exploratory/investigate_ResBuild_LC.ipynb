# %% [markdown]
# # Data Load and Investigation
#
# In this notebook, I load in the `ResBldg` data and investigate the columns to get a feel for the data types, NA values and how the data is generally structured.

# %%
# test file collect:
import pandas as pd

# real property sales df create:
res_build = pd.read_csv("../data/EXTR_ResBldg.csv")
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Preview data:

# %%
res_build.head()
# Out:
#    Major  Minor  BldgNbr  NbrLivingUnits                    Address  \
# 0  46100    935        1               1  7349   10TH AVE NW  98117
# 1  46100   1165        1               1  7342   11TH AVE NW  98117
# 2  46100   1720        1               1  7330   13TH AVE NW  98117
# 3  46100   1745        1               1  7348   13TH AVE NW  98117
# 4  46100   1930        1               1  7306   14TH AVE NW  98117
#
#   BuildingNumber Fraction DirectionPrefix                 StreetName  \
# 0          7349                            10TH
# 1          7342                            11TH
# 2          7330                            13TH
# 3          7348                            13TH
# 4          7306                            14TH
#
#   StreetType  ... FpMultiStory FpFreestanding  FpAdditional  YrBuilt  \
# 0     AVE     ...            0              0             0     1927
# 1     AVE     ...            0              0             0     2019
# ...

# %%
# determine how many entries, nulls, dtypes etc.
res_build.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515263 entries, 0 to 515262
# Data columns (total 50 columns):
# Major                 515263 non-null int64
# Minor                 515263 non-null int64
# BldgNbr               515263 non-null int64
# NbrLivingUnits        515263 non-null int64
# Address               515263 non-null object
# BuildingNumber        515263 non-null object
# Fraction              515263 non-null object
# DirectionPrefix       514721 non-null object
# StreetName            515263 non-null object
# StreetType            515263 non-null object
# DirectionSuffix       514721 non-null object
# ZipCode               469778 non-null object
# Stories               515263 non-null float64
# BldgGrade             515263 non-null int64
# BldgGradeVar          515263 non-null int64
# SqFt1stFloor          515263 non-null int64
# SqFtHalfFloor         515263 non-null int64
# SqFt2ndFloor          515263 non-null int64
# ...

# %%
# view unique col entries:
columns = res_build.columns

for col in columns:
    print(f"Unique entries for {col}: {res_build[col].unique()}")
# Out:
# Unique entries for Major: [ 46100  46400  47200 ... 374160 372850 369150]
# Unique entries for Minor: [ 935 1165 1720 ... 7332 7591 2583]
# Unique entries for BldgNbr: [ 1  2  4  3  5  6  8  7  9 10 11 12 14 15 13 16 18 19 17 29 24 28 22 30
#  21 23 20 31 26 25 27]
# Unique entries for NbrLivingUnits: [1 3 2 4 8 6 9]
# Unique entries for Address: ['7349   10TH AVE NW  98117' '7342   11TH AVE NW  98117'
#  '7330   13TH AVE NW  98117' ... '35428   55TH AVE S  '
#  '35431   56TH AVE S  ' '35418   51ST AVE S  98001']
# Unique entries for BuildingNumber: ['7349 ' '7342 ' '7330 ' ... '29555' '37246' '35256']
# Unique entries for Fraction: ['   ' 'B  ' 'A  ' 'D  ' 'c  ' 'C  ' '1/2' '0  ' 'F  ' 'NE ' 'b  ' '2  '
#  'a  ' 'E  ' '1  ' 'SW ' '2B ' 'S  ' ' B ' ' A ' 'H  ' 'G  ' '3  ' 'J  '
#  '4  ' '1D ' 'W  ' '00 ' '5  ' 'SE ' '1A ' '1B ' ' D ' '6  ' '`  ' 'C2 '
#  'C1 ' 'I  ' 'NW ' 'sw ' '14 ' '40 ' '18 ' '1C ' 'op ' '16 ' '17 ' '15 '
# ...

# %%
# generate cols to drop:
cols_to_drop = ['Address', 'BuildingNumber', 'Fraction', 'DirectionPrefix', 
                'StreetName', 'StreetType', 'DirectionSuffix', 'Obsolescence', 'BldgNbr']

res_build.drop(cols_to_drop, axis = 1, inplace = True)
res_build.head()
# Out:
#    Major  Minor  NbrLivingUnits ZipCode  Stories  BldgGrade  BldgGradeVar  \
# 0  46100    935               1   98117      1.0          7             0
# 1  46100   1165               1   98117      2.0          8             0
# 2  46100   1720               1   98117      2.0          9             0
# 3  46100   1745               1   98117      2.0          8             0
# 4  46100   1930               1   98117      1.0          7             0
#
#    SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  ...  FpSingleStory  \
# 0           960              0             0  ...              1
# 1          1600              0          1560  ...              1
# 2          1200              0          1490  ...              1
# 3           680              0           780  ...              0
# 4          1240              0             0  ...              0
#
#    FpMultiStory  FpFreestanding  FpAdditional  YrBuilt  YrRenovated  \
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
os.curdir
# Out:
# '.'

# %%
from src.data_cleaning import data_cleaning as dc

# %%
dc.maj_min_index(res_build)
# Out:
#             NbrLivingUnits ZipCode  Stories  BldgGrade  BldgGradeVar  \
# maj_min
# 0461000935               1   98117      1.0          7             0
# 0461001165               1   98117      2.0          8             0
# 0461001720               1   98117      2.0          9             0
# 0461001745               1   98117      2.0          8             0
# 0461001930               1   98117      1.0          7             0
# ...                    ...     ...      ...        ...           ...
# 3751602283               1   98001      1.0          7             0
# 3751602309               1     NaN      2.0          9             0
# 3751602361               1     NaN      2.0          9             0
# 3751602363               1     NaN      2.0          9             0
# 3751602583               1   98001      1.0          7             0
#
#             SqFt1stFloor  SqFtHalfFloor  SqFt2ndFloor  SqFtUpperFloor  \
# maj_min
# ...

# %% [markdown]
# ![image.png](attachment:c5bf1169-83e3-49b6-a498-d6c0bbafde9d.png)

# %% [markdown]
# do same for waterfront locations - 2 bar graphs of mean price for on wterfront and off waterfront

# %% [markdown]
# think about having an overview of average sale prices for different features - waterfront, nuisances, porches etc
